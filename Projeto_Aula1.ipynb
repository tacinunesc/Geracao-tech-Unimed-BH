# %% [markdown]
# <a href="https://colab.research.google.com/github/tacinunesc/Geracao-tech-Unimed-BH/blob/main/Projeto_Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto de Pandas para o bootcamp da Unimed BH

# %%
#IMPORTANDO A BIBLIOTECA 
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
#Visulizando as 5 primeiras linhas
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df = df.rename(columns={"housing_median_age":"habitação_mediana_idade", "population":"população", "households": "familias",
                   "median_income":"renda_mediana", "median_house_value":"valor_mediano_casas"})

# %%
df.head(10)
# Out:
#    longitude  latitude  habitação_mediana_idade  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                     27.0       3885.0           661.0
# 1    -118.30     34.26                     43.0       1510.0           310.0
# 2    -117.81     33.78                     27.0       3589.0           507.0
# 3    -118.36     33.82                     28.0         67.0            15.0
# 4    -119.67     36.33                     19.0       1241.0           244.0
# 5    -119.56     36.51                     37.0       1018.0           213.0
# 6    -121.43     38.63                     43.0       1009.0           225.0
# 7    -120.65     35.48                     19.0       2310.0           471.0
# 8    -122.84     38.40                     15.0       3080.0           617.0
# 9    -118.02     34.08                     31.0       2402.0           632.0
#
#    população  familias  renda_mediana  valor_mediano_casas
# 0     1537.0     606.0         6.6085             344700.0
# ...

# %%
#Total de linhas e colunas
df.shape
# Out:
# (3000, 9)

# %%
#Retornando colunas
df.columns
# Out:
# Index(['longitude', 'latitude', 'habitação_mediana_idade', 'total_rooms',
#        'total_bedrooms', 'população', 'familias', 'renda_mediana',
#        'valor_mediano_casas'],
#       dtype='object')

# %%
#Tipo de dados de cada coluna
df.dtypes
# Out:
# longitude                  float64
# latitude                   float64
# habitação_mediana_idade    float64
# total_rooms                float64
# total_bedrooms             float64
# população                  float64
# familias                   float64
# renda_mediana              float64
# valor_mediano_casas        float64
# dtype: object

# %%
#Retornar as ultimas linhas
df.tail()
# Out:
#       longitude  latitude  habitação_mediana_idade  total_rooms  \
# 2995    -119.86     34.42                     23.0       1450.0
# 2996    -118.14     34.06                     27.0       5257.0
# 2997    -119.70     36.30                     10.0        956.0
# 2998    -117.12     34.10                     40.0         96.0
# 2999    -119.63     34.42                     42.0       1765.0
#
#       total_bedrooms  população  familias  renda_mediana  valor_mediano_casas
# 2995           642.0     1258.0     607.0         1.1790             225000.0
# 2996          1082.0     3496.0    1036.0         3.3906             237200.0
# 2997           201.0      693.0     220.0         2.2895              62000.0
# 2998            14.0       46.0      14.0         3.2708             162500.0
# 2999           263.0      753.0     260.0         8.5608             500001.0

# %%
#Retorna informações estatistica
df.describe()
# Out:
#          longitude    latitude  habitação_mediana_idade   total_rooms  \
# count  3000.000000  3000.00000              3000.000000   3000.000000
# mean   -119.589200    35.63539                28.845333   2599.578667
# std       1.994936     2.12967                12.555396   2155.593332
# min    -124.180000    32.56000                 1.000000      6.000000
# 25%    -121.810000    33.93000                18.000000   1401.000000
# 50%    -118.485000    34.27000                29.000000   2106.000000
# 75%    -118.020000    37.69000                37.000000   3129.000000
# max    -114.490000    41.92000                52.000000  30450.000000
#
#        total_bedrooms     população    familias  renda_mediana  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
#Filtro
df["familias"].unique()
# Out:
# array([ 606.,  277.,  495., ...,   92.,  607., 1036.])

# %%
#Media
df["população"].mean()
# Out:
# 1402.7986666666666

# %%
#Soma
df["população"].sum()
# Out:
# 4208396.0
